# %% [markdown]
# <a href="https://colab.research.google.com/github/100abhishek/Image-Matching-Challenge-2025/blob/main/Image_Matching_Challenge_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Image Matching Chellenge 2025.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1945 entries, 0 to 1944
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_id            1945 non-null   object
#  1   dataset             1945 non-null   object
#  2   scene               1945 non-null   object
#  3   image               1945 non-null   object
#  4   rotation_matrix     1945 non-null   object
#  5   translation_vector  1945 non-null   object
# dtypes: object(6)
# memory usage: 91.3+ KB

# %%
print(df.head())
# Out:
#                                   image_id dataset     scene  \
# 0  ETs_another_et_another_et001.png_public     ETs  cluster0
# 1  ETs_another_et_another_et002.png_public     ETs  cluster0
# 2  ETs_another_et_another_et003.png_public     ETs  cluster0
# 3  ETs_another_et_another_et004.png_public     ETs  cluster0
# 4  ETs_another_et_another_et005.png_public     ETs  cluster0
#
#                           image  \
# 0  another_et_another_et001.png
# 1  another_et_another_et002.png
# 2  another_et_another_et003.png
# 3  another_et_another_et004.png
# 4  another_et_another_et005.png
#
#                                      rotation_matrix  \
# 0  0.984538905;0.811159853;0.681088421;0.84509285...
# 1  0.557144821;0.589081187;0.788143210;0.10120414...
# 2  0.070922149;0.331333475;0.055966106;0.76511642...
# 3  0.577042073;0.978031237;0.157452522;0.69871702...
# 4  0.684873837;0.658222912;0.810479111;0.15049752...
#
#                     translation_vector
# ...

# %%
print(df.isnull().sum())
# Out:
# image_id              0
# dataset               0
# scene                 0
# image                 0
# rotation_matrix       0
# translation_vector    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1945 entries, 0 to 1944
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   image_id            1945 non-null   object
#  1   dataset             1945 non-null   object
#  2   scene               1945 non-null   object
#  3   image               1945 non-null   object
#  4   rotation_matrix     1945 non-null   object
#  5   translation_vector  1945 non-null   object
# dtypes: object(6)
# memory usage: 91.3+ KB

# %%
df.describe(include="all")
# Out:
#                                               image_id  \
# count                                             1945
# unique                                            1945
# top     stairs_stairs_split_2_1710453871430.png_public
# freq                                                 1
#
#                                   dataset     scene  \
# count                                1945      1945
# unique                                 13         1
# top     pt_brandenburg_british_buckingham  cluster0
# freq                                  225      1945
#
#                             image  \
# count                        1945
# unique                       1937
# top     dioscuri_archive_0026.png
# freq                            2
#
#                                           rotation_matrix  \
# count                                                1945
# unique                                               1945
# top     0.846421877;0.866264054;0.198286104;0.53461207...
# ...

# %%
df['scene'].unique()
# Out:
# array(['cluster0'], dtype=object)

# %%
df['dataset'].value_counts()
# Out:
# dataset
# pt_brandenburg_british_buckingham    225
# pt_sacrecoeur_trevi_tajmahal         225
# imc2024_lizard_pond                  214
# imc2023_heritage                     209
# amy_gardens                          200
# pt_stpeters_stpauls                  200
# pt_piazzasanmarco_grandplace         168
# fbk_vineyard                         163
# imc2024_dioscuri_baalshamin          138
# imc2023_theather_imc2024_church       76
# imc2023_haiper                        54
# stairs                                51
# ETs                                   22
# Name: count, dtype: int64

# %%
print(f"Total images: {len(df)}")
# Out:
# Total images: 1945

# %%
print("Datasets:", df['dataset'].unique())
# Out:
# Datasets: ['ETs' 'amy_gardens' 'fbk_vineyard' 'imc2023_haiper' 'imc2023_heritage'
#  'imc2023_theather_imc2024_church' 'imc2024_dioscuri_baalshamin'
#  'imc2024_lizard_pond' 'pt_brandenburg_british_buckingham'
#  'pt_piazzasanmarco_grandplace' 'pt_sacrecoeur_trevi_tajmahal'
#  'pt_stpeters_stpauls' 'stairs']

# %%
print("Datasets:", df['dataset'].value_counts())
# Out:
# Datasets: dataset
# pt_brandenburg_british_buckingham    225
# pt_sacrecoeur_trevi_tajmahal         225
# imc2024_lizard_pond                  214
# imc2023_heritage                     209
# amy_gardens                          200
# pt_stpeters_stpauls                  200
# pt_piazzasanmarco_grandplace         168
# fbk_vineyard                         163
# imc2024_dioscuri_baalshamin          138
# imc2023_theather_imc2024_church       76
# imc2023_haiper                        54
# stairs                                51
# ETs                                   22
# Name: count, dtype: int64

# %%
print("\nNumber of images per scene:")
print(df['scene'].value_counts())
# Out:
# Number of images per scene:
# scene
# cluster0    1945
# Name: count, dtype: int64

# %%
print("\nAny images marked as outliers?")
print("outliers" in df['scene'].values)
# Out:
# Any images marked as outliers?
# False

# %%
import pandas as pd
from google.colab import files

df = pd.read_csv('/content/train_labels.csv')
df.head()
# Out:
#           dataset     scene                   image  \
# 0  imc2023_haiper  fountain  fountain_image_116.png
# 1  imc2023_haiper  fountain  fountain_image_108.png
# 2  imc2023_haiper  fountain  fountain_image_101.png
# 3  imc2023_haiper  fountain  fountain_image_082.png
# 4  imc2023_haiper  fountain  fountain_image_071.png
#
#                                      rotation_matrix  \
# 0  0.122655949;0.947713775;-0.294608417;0.1226706...
# 1  0.474305910;0.359108654;-0.803787832;0.2888416...
# 2  0.565115476;-0.138485064;-0.813305838;0.506678...
# 3  -0.308320392;-0.794654112;0.522937261;0.948141...
# 4  -0.569002830;-0.103808175;0.815757098;0.778745...
#
#                       translation_vector
# 0   0.093771314;-0.803560988;2.062001533
# 1   0.358946647;-0.797557548;1.910906929
# 2   0.146922468;-0.981392596;2.009002852
# 3   0.206413831;-1.174321103;3.667167680
# 4  -0.015140892;-1.334052012;3.488936597

# %%
ets_df = df[df['dataset'] == 'ETs']
ets_df.head()
# Out:
#      dataset     scene                   image  \
# 1872     ETs  outliers  outliers_out_et001.png
# 1873     ETs  outliers  outliers_out_et003.png
# 1874     ETs  outliers  outliers_out_et002.png
# 1875     ETs        ET            et_et007.png
# 1876     ETs        ET            et_et003.png
#
#                                         rotation_matrix  \
# 1872                nan;nan;nan;nan;nan;nan;nan;nan;nan
# 1873                nan;nan;nan;nan;nan;nan;nan;nan;nan
# 1874                nan;nan;nan;nan;nan;nan;nan;nan;nan
# 1875  0.002478910429245307;-0.12405420915233857;0.99...
# 1876  0.9640982489481782;-0.010414486123245036;0.265...
#
#                                      translation_vector
# 1872                                        nan;nan;nan
# 1873                                        nan;nan;nan
# 1874                                        nan;nan;nan
# 1875  -4.555147369216696;-0.9685255654294511;2.70579...
# 1876  3.8890600013690726;-1.7169286083058133;1.96612...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d94cb71a-02ea-40db-b064-c2f94950271c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d94cb71a-02ea-40db-b064-c2f94950271c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
from os import path
import os

# %%
with zipfile.ZipFile("ETs.zip", 'r') as zip_ref:
    zip_ref.extractall("ETs")

# %%
image_files = os.listdir("ETs")
print(f"Found {len(image_files)} image files in ETs folder.")
# Out:
# Found 1 image files in ETs folder.

# %%
import os

#go deeper into the files
image_folder_path = os.path.join("ETs", "ETs")
image_files = os.listdir(image_folder_path)
print(f"Found {len(image_files)} image files in ETs folder.")

#print how many and show first five files
print(f"Found {len(image_files)} image files in ETs folder.")
print("First five image files:")
print(image_files[:5])
# Out:
# Found 23 image files in ETs folder.
# Found 23 image files in ETs folder.
# First five image files:
# ['outliers_out_et001.png', 'LICENSE.txt', 'another_et_another_et007.png', 'et_et003.png', 'et_et001.png']

# %%
#display an image correctly
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

#pick the first image
sample_image_path = os.path.join(image_folder_path, image_files[0])

#read and display the image
sample_image = mpimg.imread(sample_image_path)
plt.imshow(sample_image)
plt.axis('off')
plt.title("First Image")
plt.show()

# %%
import pandas as pd

# Load the metadata (your Excel sheet)
metadata_df = pd.read_csv("/content/train_labels.csv")

metadata_df.head()
# Out:
#           dataset     scene                   image  \
# 0  imc2023_haiper  fountain  fountain_image_116.png
# 1  imc2023_haiper  fountain  fountain_image_108.png
# 2  imc2023_haiper  fountain  fountain_image_101.png
# 3  imc2023_haiper  fountain  fountain_image_082.png
# 4  imc2023_haiper  fountain  fountain_image_071.png
#
#                                      rotation_matrix  \
# 0  0.122655949;0.947713775;-0.294608417;0.1226706...
# 1  0.474305910;0.359108654;-0.803787832;0.2888416...
# 2  0.565115476;-0.138485064;-0.813305838;0.506678...
# 3  -0.308320392;-0.794654112;0.522937261;0.948141...
# 4  -0.569002830;-0.103808175;0.815757098;0.778745...
#
#                       translation_vector
# 0   0.093771314;-0.803560988;2.062001533
# 1   0.358946647;-0.797557548;1.910906929
# 2   0.146922468;-0.981392596;2.009002852
# 3   0.206413831;-1.174321103;3.667167680
# 4  -0.015140892;-1.334052012;3.488936597

# %%
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# Read metadata and image list
metadata_df = pd.read_csv("/content/train_labels.csv")
image_folder_path = os.path.join("ETs", "ETs")
image_files = os.listdir(image_folder_path)

# Pick the first image
sample_image_path = os.path.join(image_folder_path, image_files[0])

# Read sample image in grayscale
img1 = cv2.imread(sample_image_path, cv2.IMREAD_GRAYSCALE)

# Initialize ORB detector
orb = cv2.ORB_create()

# Detect keypoints and descriptors in the first image
kp1, des1 = orb.detectAndCompute(img1, None)

# Loop through other images in the directory and compare
matches_info = []

for image_filename in image_files:
    img2_path = os.path.join(image_folder_path, image_filename)
    img2 = cv2.imread(img2_path, cv2.IMREAD_GRAYSCALE)

    # Detect keypoints and descriptors in the second image
    kp2, des2 = orb.detectAndCompute(img2, None)

    # Check if descriptors are None
    if des1 is None or des2 is None:
        print(f"Skipping {image_filename} due to empty descriptors.")
        continue

    # Use Brute Force Matcher (BFMatcher)
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

    # Ensure descriptors are of the same type
    des1 = np.uint8(des1)
    des2 = np.uint8(des2)

    matches = bf.match(des1, des2)

    # Sort matches based on distance (best matches first)
    matches = sorted(matches, key=lambda x: x.distance)

    # Get number of matches
    num_matches = len(matches)

    # Only consider images with a reasonable number of matches
    if num_matches > 10:  # Adjust threshold as needed
        # Retrieve metadata of matching image
        matched_metadata = metadata_df[metadata_df['image'] == image_filename]

        if not matched_metadata.empty:
            rotation_matrix_str = matched_metadata.iloc[0]['rotation_matrix']
            translation_vector_str = matched_metadata.iloc[0]['translation_vector']

            # Convert string of matrices into numpy arrays
            rotation_matrix = np.array([float(x) for x in rotation_matrix_str.split(';')]).reshape(3, 3)
            translation_vector = np.array([float(x) for x in translation_vector_str.split(';')])

            # Store image comparison and associated metadata
            matches_info.append({
                'image': image_filename,
                'num_matches': num_matches,
                'rotation_matrix': rotation_matrix,
                'translation_vector': translation_vector
            })

# Sort by number of matches
matches_info_sorted = sorted(matches_info, key=lambda x: x['num_matches'], reverse=True)

# Show the most matched images with their metadata
print(f"Top matched images (based on keypoint matches):")
for match in matches_info_sorted[:5]:  # Show top 5
    print(f"Image: {match['image']}, Matches: {match['num_matches']}")
    print(f"Rotation Matrix:\n{match['rotation_matrix']}")
    print(f"Translation Vector: {match['translation_vector']}")
# Out:
# Skipping LICENSE.txt due to empty descriptors.
# Top matched images (based on keypoint matches):
# Image: outliers_out_et001.png, Matches: 451
# Rotation Matrix:
# [[nan nan nan]
#  [nan nan nan]
#  [nan nan nan]]
# Translation Vector: [nan nan nan]
# Image: et_et000.png, Matches: 137
# Rotation Matrix:
# [[ 0.94045377  0.05238928  0.33586019]
#  [ 0.02047008  0.97753015 -0.2097994 ]
#  [-0.3393047   0.20418172  0.9182495 ]]
# Translation Vector: [ 3.51884318 -1.65835291  1.53575827]
# Image: et_et001.png, Matches: 134
# Rotation Matrix:
# [[ 0.82673625  0.12222459  0.54915237]
#  [-0.02072796  0.98207004 -0.18737341]
#  [-0.56220773  0.14352558  0.81444636]]
# Translation Vector: [ 1.58418909 -1.88999207  1.92605492]
# Image: another_et_another_et006.png, Matches: 127
# Rotation Matrix:
# [[ 0.9161188   0.18489875 -0.35572291]
#  [-0.22337537  0.97222072 -0.06993077]
#  [ 0.33291107  0.14352463  0.93197151]]
# Translation Vector: [-0.58871943 -0.69112361  0.95888166]
# ...

# %%
# Pick the top matched image (with the highest number of matches)
top_match = matches_info_sorted[2]
top_image_path = os.path.join(image_folder_path, top_match['image'])
img2 = cv2.imread(top_image_path, cv2.IMREAD_GRAYSCALE)

# Detect keypoints and descriptors in the top matched image
kp2, des2 = orb.detectAndCompute(img2, None)

# Use Brute Force Matcher to find the best matches between the two sets of descriptors
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1, des2)
matches = sorted(matches, key=lambda x: x.distance)

# Draw the matches between the two images
img_matches = cv2.drawMatches(img1, kp1, img2, kp2, matches[:100], None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# Display the image with matches
plt.imshow(img_matches)
plt.axis('off')
plt.title("Top 100 Matches Between Images")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ensure t1 and t2 are (3,) shape instead of (3,1)
t1 = t1.reshape(3,)
t2 = t2.reshape(3,)

# Compute camera centers in world coordinates
C1 = -R1.T @ t1
C2 = -R2.T @ t2

# Camera viewing directions (Z-axis)
direction1 = R1 @ np.array([0, 0, 1])
direction2 = R2 @ np.array([0, 0, 1])

# Flatten everything to (3,) for plotting
C1 = C1.flatten()
C2 = C2.flatten()
direction1 = direction1.flatten()
direction2 = direction2.flatten()

# Plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot triangulated 3D points
ax.scatter(points3D[0], points3D[1], points3D[2], c='red', marker='o', label='3D Points')

# Plot camera 1 as a direction line
ax.quiver(C1[0], C1[1], C1[2],
          direction1[0], direction1[1], direction1[2],
          length=10, color='blue', label='Camera 1')
ax.text(C1[0], C1[1], C1[2], "Cam 1", color='blue')

# Plot camera 2 as a direction line
ax.quiver(C2[0], C2[1], C2[2],
          direction2[0], direction2[1], direction2[2],
          length=10, color='green', label='Camera 2')
ax.text(C2[0], C2[1], C2[2], "Cam 2", color='green')

# Axes labels and plot
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title("3D Points and Camera View Directions")
ax.legend()
plt.show()

# %%
# Keep only points with positive depth (in front of both cameras)
valid_mask = (points4D[2] > 0)
points3D_clean = points4D[:3, valid_mask]

# %%
print("Original 3D points shape:", points3D.shape)
print("Cleaned 3D points shape:", points3D_clean.shape)
# Out:
# Original 3D points shape: (3, 3)
# Cleaned 3D points shape: (3, 0)

# %%
print("Raw triangulated points:")
print(points3D)
# Out:
# Raw triangulated points:
# [[-21.963448  -16.97724   -11.988244 ]
#  [ -3.4940467   1.4979292   6.493345 ]
#  [ 79.86102    79.88657    79.915054 ]]

# %%
# Mask to check if all coordinates are finite
valid_mask = np.isfinite(points3D).all(axis=0)
print("Valid mask:", valid_mask)

# Apply the mask
points3D_clean = points3D[:, valid_mask]
print("Cleaned 3D points shape:", points3D_clean.shape)

# Optional check if any points remain
if points3D_clean.shape[1] == 0:
    raise ValueError("No valid 3D points after filtering. Check triangulation.")
# Out:
# Valid mask: [ True  True  True]
# Cleaned 3D points shape: (3, 3)

# %%
import cv2

# Ensure translation vector is in the right format
t2 = t2.astype(np.float32)

# Convert rotation matrix to rotation vector
rvec2, _ = cv2.Rodrigues(R2)

# Prepare 3D points for projection (shape: N x 3)
points_3d_for_proj = points3D_clean.T.astype(np.float32)  # shape (N, 3)

# Project onto second image
proj_points2, _ = cv2.projectPoints(points_3d_for_proj, rvec2, t2, K, None)

# Convert from (N, 1, 2) to (N, 2)
proj_points2 = proj_points2.reshape(-1, 2)

# Display some projected points
print("Projected 2D points on image 2:")
print(proj_points2[:10])
# Out:
# Projected 2D points on image 2:
# [[110.00071 204.99873]
#  [160.00075 255.00056]
#  [210.00076 305.00247]]

# %%
import cv2
import matplotlib.pyplot as plt

# Load the second image again (grayscale or color, your choice)
img2 = cv2.imread(top_image_path)  # Already defined earlier

# Plot the image and overlay the projected 2D points
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))  # convert to RGB for matplotlib
plt.scatter(proj_points2[:, 0], proj_points2[:, 1], c='red', s=10, label='Projected 3D points')
plt.title("Reprojected 3D Points onto Image 2")
plt.legend()
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample camera extrinsics (you should replace these with your actual R1, t1, R2, t2)
# These are placeholders
R1 = np.eye(3)
t1 = np.array([[0], [0], [0]])
R2 = np.eye(3)
t2 = np.array([[1], [0], [0]])

# Sample triangulated 3D points
points3D_clean = np.random.rand(3, 100)  # shape (3, N)

# Compute camera centers in world coordinates
C1 = -R1.T @ t1
C2 = -R2.T @ t2

# Viewing directions (Z-axis of the camera)
z1 = R1 @ np.array([0, 0, 1])
z2 = R2 @ np.array([0, 0, 1])

# Normalize viewing directions
z1 = z1 / np.linalg.norm(z1)
z2 = z2 / np.linalg.norm(z2)

# Set the length of the camera direction lines
line_length = 0.5

# Compute line end points for cameras
C1_end = C1.flatten() + z1 * line_length
C2_end = C2.flatten() + z2 * line_length

# Plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot 3D points
ax.scatter(points3D_clean[0], points3D_clean[1], points3D_clean[2], c='red', marker='o', label='3D Points')

# Plot camera directions as lines
ax.plot([C1[0,0], C1_end[0]], [C1[1,0], C1_end[1]], [C1[2,0], C1_end[2]], color='blue', linewidth=2, label='Camera 1')
ax.plot([C2[0,0], C2_end[0]], [C2[1,0], C2_end[1]], [C2[2,0], C2_end[2]], color='green', linewidth=2, label='Camera 2')

# Plot camera centers as large points (optional)
ax.scatter(C1[0], C1[1], C1[2], c='blue', s=50)
ax.scatter(C2[0], C2[1], C2[2], c='green', s=50)

# Labels and legend
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title("3D Points and Camera Viewing Directions (Lines)")
ax.legend()
ax.view_init(elev=20, azim=120)

plt.tight_layout()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the two images in grayscale
img1_path = '/content/another_et_another_et004.png'  # Replace with your actual path
img2_path = '/content/another_et_another_et005.png'  # Replace with your actual path

img1 = cv2.imread(img1_path, cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread(img2_path, cv2.IMREAD_GRAYSCALE)

# Initialize ORB detector
orb = cv2.ORB_create(nfeatures=1000)

# Detect keypoints and compute descriptors
kp1, des1 = orb.detectAndCompute(img1, None)
kp2, des2 = orb.detectAndCompute(img2, None)

# Create BFMatcher with Hamming distance
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Match descriptors
matches = bf.match(des1, des2)

# Sort the matches based on distance (lower is better)
matches = sorted(matches, key=lambda x: x.distance)

# Draw top 50 matches
matched_img = cv2.drawMatches(img1, kp1, img2, kp2, matches[:50], None,
                              flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# Display the matches
plt.figure(figsize=(16, 8))
plt.imshow(matched_img, cmap='gray')
plt.title("Top 50 Feature Matches")
plt.axis('off')
plt.show()

# %%
import torch
import torchvision.models as models
import torch.nn as nn
import torchvision.transforms as transforms
from PIL import Image
import os
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load pretrained ResNet18 and remove the classification head
resnet = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
feature_extractor = nn.Sequential(*list(resnet.children())[:-1])
feature_extractor.to(device)
feature_extractor.eval()
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# Transform to preprocess images
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

def extract_features(img_path):
    image = Image.open(img_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)
    with torch.no_grad():
        features = feature_extractor(image)
    return features.view(-1).cpu().numpy()

# %%
import os
from google.colab import files

# Create folder if it doesn't exist
image_folder = '/content/images'
os.makedirs(image_folder, exist_ok=True)

print("⬆️ Upload all your test images (used in test_pairs.csv)")
uploaded = files.upload()

# Move uploaded files to the folder
for filename in uploaded.keys():
    os.rename(filename, os.path.join(image_folder, filename))
print("✅ All images moved to:", image_folder)
# Out:
# ⬆️ Upload all your test images (used in test_pairs.csv)
#      <input type="file" id="files-9fb611d3-dc61-4d1c-915a-54e9f1d6c172" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9fb611d3-dc61-4d1c-915a-54e9f1d6c172">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import os
import pandas as pd
import itertools

# Folder where images are stored
image_folder = '/content/images'

# Get all image filenames
image_files = sorted([f for f in os.listdir(image_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

# Create unique pairs (excluding pairs like (img, img))
image_pairs = list(itertools.combinations(image_files, 2))

# Convert to DataFrame
df_pairs = pd.DataFrame(image_pairs, columns=['image1', 'image2'])

# Save to CSV
test_pairs_path = '/content/test_pairs.csv'
df_pairs.to_csv(test_pairs_path, index=False)

print(f"✅ Created {len(df_pairs)} image pairs and saved to {test_pairs_path}")
# Out:
# ✅ Created 15 image pairs and saved to /content/test_pairs.csv

# %%
import cv2
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

# Load the CSV with image pairs
pairs_csv = '/content/test_pairs.csv'
image_folder = '/content/images'
df = pd.read_csv(pairs_csv)

# ORB feature extractor
orb = cv2.ORB_create()

# Function to compute keypoints and descriptors
def get_descriptors(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return None, None
    kp, des = orb.detectAndCompute(img, None)
    return kp, des

# Function to match features and count good matches
def compute_match_score(des1, des2):
    if des1 is None or des2 is None:
        return 0
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(des1, des2)
    matches = sorted(matches, key=lambda x: x.distance)
    return len(matches)

# Loop through image pairs and compute predictions
predictions = []
for _, row in tqdm(df.iterrows(), total=len(df)):
    img1_path = os.path.join(image_folder, row['image1'])
    img2_path = os.path.join(image_folder, row['image2'])

    kp1, des1 = get_descriptors(img1_path)
    kp2, des2 = get_descriptors(img2_path)

    match_score = compute_match_score(des1, des2)

    # You can tune this threshold based on visual inspection
    prediction = 1 if match_score > 15 else 0
    predictions.append(prediction)

# Add predictions to the dataframe and save
df['prediction'] = predictions
submission_path = '/content/submission.csv'
df.to_csv(submission_path, index=False)

print(f"✅ Submission file created: {submission_path}")
# Out:
# 100%|██████████| 15/15 [00:02<00:00,  6.95it/s]
# ✅ Submission file created: /content/submission.csv

# %%
import pandas as pd

# Load the submission CSV
submission_path = '/content/submission.csv'
df = pd.read_csv(submission_path)

# Display the first few rows
df.head()
# Out:
#                 image1                               image2  prediction
# 0  baalshamin_182z.png                    baalshamin_25.png           1
# 1  baalshamin_182z.png                     lizard_00195.png           1
# 2  baalshamin_182z.png                     lizard_00203.png           1
# 3  baalshamin_182z.png  sacre_coeur_28088482_1061487806.png           1
# 4  baalshamin_182z.png  sacre_coeur_30642459_5864476232.png           1

# %%
df['prediction'].value_counts()
# Out:
# prediction
# 1    15
# Name: count, dtype: int64

# %%
import cv2
import matplotlib.pyplot as plt
import os
import random

# Set folder path
image_folder = '/content/images'

# Randomly pick a few rows to visualize
sample_rows = df.sample(5)

for _, row in sample_rows.iterrows():
    img1_path = os.path.join(image_folder, row['image1'])
    img2_path = os.path.join(image_folder, row['image2'])

    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)

    # Convert BGR to RGB for display
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

    fig, axs = plt.subplots(1, 2, figsize=(10, 4))
    axs[0].imshow(img1)
    axs[0].set_title(f"Image 1: {row['image1']}")
    axs[0].axis('off')

    axs[1].imshow(img2)
    axs[1].set_title(f"Image 2: {row['image2']}")
    axs[1].axis('off')

    match_text = "MATCH" if row['prediction'] == 1 else "NO MATCH"
    plt.suptitle(f"Prediction: {match_text}", fontsize=14, color='green' if row['prediction'] == 1 else 'red')
    plt.show()

# %%
from google.colab import files
files.download('submission.csv')
